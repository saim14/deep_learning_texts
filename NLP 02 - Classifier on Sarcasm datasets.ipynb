# %%
import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
    -O /tmp/sarcasm.json
# Out:
# --2021-03-08 09:38:08--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.188.128, 64.233.189.128, 108.177.97.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.188.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  --.-KB/s    in 0.05s
#
# 2021-03-08 09:38:08 (113 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]

# %%
with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)

sentences = []
labels = []

for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
# Need this block to get it to work with TensorFlow 2.x
import numpy as np
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 16)           160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 24)                408
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 160,433
# Trainable params: 160,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/30
# 625/625 - 6s - loss: 0.6710 - accuracy: 0.5750 - val_loss: 0.6113 - val_accuracy: 0.6636
# Epoch 2/30
# 625/625 - 3s - loss: 0.4620 - accuracy: 0.8164 - val_loss: 0.3920 - val_accuracy: 0.8392
# Epoch 3/30
# 625/625 - 3s - loss: 0.3202 - accuracy: 0.8731 - val_loss: 0.3537 - val_accuracy: 0.8541
# Epoch 4/30
# 625/625 - 3s - loss: 0.2638 - accuracy: 0.8978 - val_loss: 0.3473 - val_accuracy: 0.8529
# Epoch 5/30
# 625/625 - 3s - loss: 0.2271 - accuracy: 0.9129 - val_loss: 0.3479 - val_accuracy: 0.8550
# Epoch 6/30
# 625/625 - 3s - loss: 0.1990 - accuracy: 0.9250 - val_loss: 0.3590 - val_accuracy: 0.8523
# Epoch 7/30
# 625/625 - 3s - loss: 0.1775 - accuracy: 0.9329 - val_loss: 0.3616 - val_accuracy: 0.8533
# Epoch 8/30
# 625/625 - 3s - loss: 0.1603 - accuracy: 0.9409 - val_loss: 0.3738 - val_accuracy: 0.8563
# Epoch 9/30
# 625/625 - 3s - loss: 0.1422 - accuracy: 0.9482 - val_loss: 0.4037 - val_accuracy: 0.8462
# Epoch 10/30
# 625/625 - 3s - loss: 0.1285 - accuracy: 0.9549 - val_loss: 0.4132 - val_accuracy: 0.8502
# Epoch 11/30
# 625/625 - 3s - loss: 0.1172 - accuracy: 0.9589 - val_loss: 0.4419 - val_accuracy: 0.8444
# Epoch 12/30
# 625/625 - 3s - loss: 0.1089 - accuracy: 0.9614 - val_loss: 0.4572 - val_accuracy: 0.8474
# Epoch 13/30
# 625/625 - 3s - loss: 0.0980 - accuracy: 0.9664 - val_loss: 0.4999 - val_accuracy: 0.8363
# Epoch 14/30
# 625/625 - 3s - loss: 0.0901 - accuracy: 0.9698 - val_loss: 0.5371 - val_accuracy: 0.8337
# Epoch 15/30
# 625/625 - 3s - loss: 0.0827 - accuracy: 0.9717 - val_loss: 0.5393 - val_accuracy: 0.8393
# Epoch 16/30
# 625/625 - 3s - loss: 0.0749 - accuracy: 0.9755 - val_loss: 0.5676 - val_accuracy: 0.8384
# Epoch 17/30
# 625/625 - 3s - loss: 0.0695 - accuracy: 0.9780 - val_loss: 0.6055 - val_accuracy: 0.8313
# Epoch 18/30
# 625/625 - 3s - loss: 0.0642 - accuracy: 0.9798 - val_loss: 0.6345 - val_accuracy: 0.8322
# Epoch 19/30
# 625/625 - 3s - loss: 0.0589 - accuracy: 0.9808 - val_loss: 0.6788 - val_accuracy: 0.8286
# Epoch 20/30
# 625/625 - 3s - loss: 0.0539 - accuracy: 0.9832 - val_loss: 0.7009 - val_accuracy: 0.8278
# Epoch 21/30
# 625/625 - 3s - loss: 0.0493 - accuracy: 0.9850 - val_loss: 0.7797 - val_accuracy: 0.8231
# Epoch 22/30
# 625/625 - 3s - loss: 0.0470 - accuracy: 0.9851 - val_loss: 0.7889 - val_accuracy: 0.8210
# Epoch 23/30
# 625/625 - 3s - loss: 0.0414 - accuracy: 0.9877 - val_loss: 0.8137 - val_accuracy: 0.8225
# Epoch 24/30
# 625/625 - 3s - loss: 0.0404 - accuracy: 0.9872 - val_loss: 0.8394 - val_accuracy: 0.8222
# Epoch 25/30
# 625/625 - 3s - loss: 0.0353 - accuracy: 0.9897 - val_loss: 0.8920 - val_accuracy: 0.8185
# Epoch 26/30
# 625/625 - 3s - loss: 0.0345 - accuracy: 0.9902 - val_loss: 0.9267 - val_accuracy: 0.8179
# Epoch 27/30
# 625/625 - 3s - loss: 0.0305 - accuracy: 0.9911 - val_loss: 0.9501 - val_accuracy: 0.8199
# Epoch 28/30
# 625/625 - 3s - loss: 0.0295 - accuracy: 0.9912 - val_loss: 1.0302 - val_accuracy: 0.8161
# Epoch 29/30
# 625/625 - 3s - loss: 0.0265 - accuracy: 0.9927 - val_loss: 1.0313 - val_accuracy: 0.8155
# Epoch 30/30
# 625/625 - 3s - loss: 0.0233 - accuracy: 0.9938 - val_loss: 1.0608 - val_accuracy: 0.8156

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_sentence(training_padded[0]))
print(training_sentences[2])
print(labels[2])
# Out:
# former <OOV> store clerk sues over secret 'black <OOV> for minority shoppers ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
# mom starting to fear son's web series closest thing she will have to grandchild
# 1

# %%
sentence = ["granny starting to fear spiders in the garden might be real", "game of thrones season finale showing this sunday night"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# [[9.5578092e-01]
#  [5.7261236e-06]]

# %%
def is_sarcasm(sentence):
  sequences = tokenizer.texts_to_sequences(sentence)
  padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
  pred_prob = model.predict(padded)
  if pred_prob > 0.5:
    print(sentence, "\nis sarcastic")
  else:
    print(sentence, "\nis not sarcastic)
# Out:
#   File "<ipython-input-1-be4fad17ad69>", line 4
#     pred_prob = model.predict(padded))
#                                      ^
# SyntaxError: invalid syntax
